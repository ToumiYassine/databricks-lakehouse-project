# %%
# !pip install pandas

# %%
import pandas as pd
df_cust = pd.read_csv('/Volumes/lakehouse/bronze/raw_sources/CUST_AZ12.csv')
display(df_cust)

# %%
import pandas as pd
df_loc = pd.read_csv('/Volumes/lakehouse/bronze/raw_sources/LOC_A101.csv')
display(df_loc)

# %%
import pandas as pd
df_px = pd.read_csv('/Volumes/lakehouse/bronze/raw_sources/PX_CAT_G1V2.csv')
display(df_px)

# %%
import pandas as pd
df_sales = pd.read_csv('/Volumes/lakehouse/bronze/raw_sources/sales_details.csv')
display(df_sales)

# %%
import pandas as pd
df_prd = pd.read_csv('/Volumes/lakehouse/bronze/raw_sources/prd_info.csv')
display(df_prd)

# %%
import pandas as pd
df_cust_info = pd.read_csv('/Volumes/lakehouse/bronze/raw_sources/cust_info.csv')
display(df_cust_info)

# %%
spark_df_cust = spark.createDataFrame(df_cust)

spark_df_cust.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("lakehouse.bronze.erp_cust")

# %%
spark_df_loc = spark.createDataFrame(df_loc)

spark_df_loc.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("lakehouse.bronze.erp_loc")

# %%
spark_df_px = spark.createDataFrame(df_px)

spark_df_px.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("lakehouse.bronze.erp_px")

# %%
spark_df_cust_info = spark.createDataFrame(df_cust_info)

spark_df_cust_info.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("lakehouse.bronze.crm_cust_info")

# %%
spark_df_prd = spark.createDataFrame(df_prd)

spark_df_prd.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("lakehouse.bronze.crm_prd")

# %%
spark_df_sales = spark.createDataFrame(df_sales)

spark_df_sales.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("lakehouse.bronze.crm_sales")
