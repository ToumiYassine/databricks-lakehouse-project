# %%
gold_notebooks = [
    "/Workspace/Users/yassine.toumi159@gmail.com/databricks-lakehouse-project/Gold/Gold_dim_productss",
    "/Workspace/Users/yassine.toumi159@gmail.com/databricks-lakehouse-project/Gold/Gold_fact_sales",
    "/Workspace/Users/yassine.toumi159@gmail.com/databricks-lakehouse-project/Gold/Gold_dim_customers"
]

for nb in gold_notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
