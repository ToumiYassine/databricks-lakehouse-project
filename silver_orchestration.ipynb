# %%
silver_notebooks = [
    "/Workspace/Users/yassine.toumi159@gmail.com/databricks-lakehouse-project/Silver/crm/Silver_crm_cust_info",
    "/Workspace/Users/yassine.toumi159@gmail.com/databricks-lakehouse-project/Silver/crm/Silver_crm_prd_info",
    "/Workspace/Users/yassine.toumi159@gmail.com/databricks-lakehouse-project/Silver/crm/Silver_crm_sales",
    "/Workspace/Users/yassine.toumi159@gmail.com/databricks-lakehouse-project/Silver/erp/Silver_erp_cust",
    "/Workspace/Users/yassine.toumi159@gmail.com/databricks-lakehouse-project/Silver/erp/Silver_erp_location",
    "/Workspace/Users/yassine.toumi159@gmail.com/databricks-lakehouse-project/Silver/erp/Silver_erp_px_cat"
]

for nb in silver_notebooks:
    print(f"➡️ Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
    print(f"✅ Finished {nb}")
