-- %%
select * from lakehouse.bronze.erp_px

-- %%
SELECT ID, COUNT(*) AS cnt
FROM lakehouse.bronze.erp_px
GROUP BY ID
HAVING COUNT(*) > 1;

-- %%
  DELETE FROM lakehouse.bronze.erp_px
WHERE ID IS NULL;

select * from lakehouse.bronze.erp_px

-- %%
CREATE OR REPLACE TABLE lakehouse.silver.erp_category AS
SELECT
    CAST(ID AS STRING) AS Categoty_id,
    CAST(CAT AS STRING) AS Category,
    CAST(SUBCAT AS STRING) AS Subcategory,
    CAST(MAINTENANCE AS STRING) AS Maintenance

FROM lakehouse.bronze.erp_px;

-- %%
select * from lakehouse.silver.erp_category
