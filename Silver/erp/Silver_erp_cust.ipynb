-- %%
--select * from lakehouse.bronze.erp_cust

-- %%
/*SELECT CID, COUNT(*) AS cnt
FROM lakehouse.bronze.erp_cust
GROUP BY CID
HAVING COUNT(*) > 1;*/

-- %%
  DELETE FROM lakehouse.bronze.erp_cust
WHERE CID IS NULL;

--select * from lakehouse.bronze.erp_cust

-- %%
CREATE OR REPLACE TABLE lakehouse.silver.erp_cust AS
SELECT
    CAST(CID AS STRING) AS Customer_id,
    CAST(BDATE AS DATE) AS Date_birth ,
    SUBSTRING(CUSTOMER_ID, 4) AS CUST_ID,
    CAST(GEN AS STRING) AS Customer_Gender

FROM lakehouse.bronze.erp_cust;

-- %%
--select * from lakehouse.silver.erp_cust

-- %%
SELECT 1;
